# %% [markdown]
# # Exploratory Data Analysis on YouTube data.

# %% [markdown]
# ## Q.1) Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
#Required libraries:
import pandas as pd

# %%
#Read the dataset
data_set = pd.read_csv("youtube_dislike_dataset.csv")
data_set
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
# Retrieve top 5 records
data_set.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
#Retrieve bottom 5 Records.
data_set.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# ## Q.2). Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
data_set.shape      #checking the shape of the dataframe.
data_set.info()     #checking the info of the dataframe.
data_set.dtypes     #checking the data types of the dataset.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# ...

# %% [markdown]
# ### Inferences :

# %% [markdown]
# - Shape of the dataset:
# - The dataset consists of 37,422 rows and 12 columns.
#
# - Data Types:
# - There are 4 columns with data type int64, representing numerical data (view_count, likes, dislikes, comment_count).
# - There are 8 columns with data type object, representing categorical data (video_id, title, channel_id, channel_title, published_at,   tags,     description, comments).
#
# - The dataset seems to be relatively large in terms of memory usage, occupying approximately 3.4+ MB of memory.
# - There are no missing values in most columns, except for the "comments" column, which has some missing values (37264 non-null entries out of     37422 total entries).

# %% [markdown]
# ## Q.3)check for the Percentage of the missing values and drop or impute them.

# %%
#checking the percentage of missing values.
data_set.isnull().mean()*100
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %%
# Dropping comments column
data_set.drop(columns = ["comments"],inplace=True)

# %% [markdown]
# ##  Q4). Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
#statistics summary of data belonging to numerical columns.
print("Statistical summary of data belonging to numerical columns:")
data_set.describe()
# Out:
# Statistical summary of data belonging to numerical columns:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
#statistics summary of data belonging to categorical columns:
print("Statistical summary of data belonging to categorical columns:")
data_set.describe(include=["object"])
# Out:
# Statistical summary of data belonging to categorical columns:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description
# count                 37422  37422       37422
# unique                36772  28799       35630
# top     2020-10-16 04:00:10
# freq                      6   3817         589

# %% [markdown]
# ## Inferences :

# %% [markdown]
#  From the statistics summary, we can infer the below findings :
#  - From the statistics summary of numerical columns:
# -  view count:
#  It specifies that the minimum view count is about 20,368 and the mean view count is nearly 5.7 million,
#  which means some videos have comparatively few views.
#  The maximum view count is nearly 1.32 billion,showing that there are videos with very high view counts.
#  And standared deviation is about 24.3 million with a wide range data.
# - Dislikes:
#    Some video's have zero likes,as the minimum value is 0.And the maximum number of dislikes is nearly 2.4 million.
#    The mean number of dislikes is nearly 4990, gives an idea about a moderate number of dislikes on average.
#    25% of the videos have fewer than 281 dislikes.The data has relatively high standard deviation,suggesting variability in the number of      - dislikes.
# - Likes :
#    Some videos have zeros likes, as the minimum value is 0. And the maximum number of likes is nearly 31.8 million.
#    The mean number of likes is about 166814, suggesting a significant number of likes on average.The data has a relatively high standared deviation indicating variability in the number of likes.25% of the videos have fewer than 13,233 likes
# - comment count:
#     Some video's have zero comments,as the minimum value is 0.The maximum comment count is nearly 16.1 million.
#     The mean comment is about 9925 indicating a number of comments on average.The data has a wide range with a standared deviation of approximately 117,100 indicating significant variability in the number of comments.25% of the videos have fewer than 900 comments.
#     These  inference provide insights into the distribution and variation of the numerical data in the dataset.
#
#  Where as the Categorical column provides us with a good understanding of the dataset.
# - The channel id and channel title columns have 10,961 and 10,883 unique values respectively.The most frequently occurring channel title  is "Sky Sports Football". And most frequently occurring channel id is UCNAf1k0yIjyGu3k9BwAg3lg this channel id appears 533 times.
# - The tags and description columns have 28,799 and 35,630 unique values,respectively.The most frequent description appears 589 times,but the specific description  is not mentioned in the summary. And the most frequent tag appears 3817 times but the specific tag is not mentioned in the summary.
# - on the published at column, we can conclude that, the videos were published on various dates and times.
# - The title column has 37,113 unique titles, with "www UCNAf1k0yIjyGu3k9BwAg3lg" being the most frequent title.
# - The video id column has 37,422 unique values, indicating that each video has a unique identifier.

# %% [markdown]
# ## Q.5) Convert datatype of column published_at from object to pandas datetime.

# %%
 #Conversion of column published_at from object to pandas datetime.
data_set["published_at"]= pd.to_datetime(data_set["published_at"])
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  datetime64[ns]
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# ### Q.6) Create a new column as 'published_month' using the column published_at (display the months only)

# %%
data_set['published_at']
# Out:
# 0       2021-07-01 10:00:00
# 1       2021-06-10 16:00:00
# 2       2021-09-20 01:03:32
# 3       2021-03-03 10:00:17
# 4       2021-12-07 13:00:00
#                 ...
# 37417   2021-02-12 05:03:49
# 37418   2021-01-16 05:39:05
# 37419   2021-06-02 09:00:10
# 37420   2020-10-20 20:59:30
# 37421   2021-05-23 21:00:31
# Name: published_at, Length: 37422, dtype: datetime64[ns]

# %%
data_set['published_month']=data_set["published_at"].dt.month
data_set
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ## Q.7). Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
data_set["published_month"]=data_set["published_at"].dt.strftime('%b')
data_set
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ## Q.8). Find the number of videos published each month and arrange the months in a decreasing order based on the video count.

# %%
#sorting the Count of videos published per month in descending order.
monthly_video_counts=data_set.groupby("published_month")["video_id"].count().sort_values(ascending =False)
monthly_video_counts
# Out:
# published_month
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: video_id, dtype: int64

# %% [markdown]
# ## Q.9). Find the count of unique video_id, channel_id and channel_title.

# %%
#Count of unique video_id
unique_video_count=data_set["video_id"].nunique()
print(f"unique_video_count is:{(unique_video_count)}")

#Count of unique channel_id
unique_channel_count = data_set["channel_id"].nunique()
print(f"unique_channel_count is:{unique_channel_count}")

#Count of unique channel_title
unique_channel_title_count = data_set["channel_title"].nunique()
print(f"unique_channel_title_count is: {unique_channel_title_count}")
# Out:
# unique_video_count is:37422
# unique_channel_count is:10961
# unique_channel_title_count is: 10883

# %% [markdown]
# ### Q.10). Find the top10 channel names having the highest number of videos in the dataset and the bottom10 having lowest number of videos.

# %%
# top10 channel names having the highest number of videos in the dataset 
top_10_channels  = data_set.groupby(["channel_title"])["title"].count().sort_values(ascending=False).head(10)
print(f"top_10_channels name is :{top_10_channels }")

# bottom10 channel names having the lowest number of videos in the dataset 
bottom_10_channels  = data_set.groupby(["channel_title"])["title"].count().sort_values(ascending=True).head(10)
print(f"bottom_10_channels names is :{bottom_10_channels}")
# Out:
# top_10_channels name is :channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: title, dtype: int64
# bottom_10_channels names is :channel_title
#    SilverName                   1
# Mini Muka                       1
# Mini Ladd                       1
# MindYourLogic                   1
# Mind Body Tonic With Dr Sita    1
# Mimi Ar                         1
# Millyz                          1
# Milkair                         1
# Milissa Grande                  1
# MikuruSong                      1
# Name: title, dtype: int64

# %% [markdown]
# ## Q.11) Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
#Finding the title of the video having least number of likes. 
video_min_likes    = data_set["likes"].min()
video_min_likes_title = data_set[data_set["likes"] == video_min_likes  ]["title"].values[0]
print(f"Title of the videos with minimum likes: {[video_min_likes_title]}")
# Out:
# Title of the videos with minimum likes: ['Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News']

# %%
#Finding the title of the video having least number of likes. 
video_max_likes  = data_set["likes"].max()
video_max_likes_title  = data_set[data_set["likes"] == video_max_likes ]["title"].values[0]
print(f"Title of the videos with maximum likes: {[video_max_likes_title]}")
# Out:
# Title of the videos with maximum likes: ["BTS () 'Dynamite' Official MV"]

# %% [markdown]
# ### Inferences:

# %% [markdown]
# - "BTS () 'Dynamite' Official MV" has collected the maximum number of likes, suggesting that it is highly popular and well-received by the audience. This could be attributed to the immense popularity of BTS and their strong fanbase, as well as the quality and appeal of the music video itself.
# - "Kim Kardashian's Must-See Moments on 'Saturday Night Live' | E! News" has the minimum number of likes, indicating that it may not have resonated well with the audience. The low number of likes could be due to various factors such as the content of the video, viewer preferences, or the specific audience for this type of content.

# %% [markdown]
# ### Q.12)Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
# the title of the video having least number of dislikes.
video_min_dislikes  = data_set["dislikes"].min()
video_min_dislikes_title = data_set[data_set["dislikes"] == video_min_dislikes ]["title"].values[0]

print(f"The title of the video with minimum dislikes is:{video_min_dislikes_title }")
video_min_dislikes_title
# Out:
# The title of the video with minimum dislikes is:Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News
# 'Kim Kardashian\'s Must-See Moments on "Saturday Night Live" | E! News'

# %%
# the title of the video having Maximum number of dislikes.
video_max_dislikes  = data_set["dislikes"].max()
video_max_dislikes_title  = data_set[data_set["dislikes"] == video_max_dislikes ]["title"].values[0]

print(f"The title of the video with Maximum dislikes is:{video_max_dislikes_title}")
video_max_dislikes_title
# Out:
# The title of the video with Maximum dislikes is:Cuties | Official Trailer | Netflix
# 'Cuties | Official Trailer | Netflix'

# %% [markdown]
# ### Inferences:

# %% [markdown]
# - "Cuties | Official Trailer | Netflix" has received the maximum number of dislikes, suggesting that this particular trailer was highly disliked by a significant portion of the audience. Possible reasons for the high number of dislikes could be related to the trailer's content, messaging, or controversy surrounding the film "Cuties."
# - "Kim Kardashian's Must-See Moments on 'Saturday Night Live' | E! News" has the minimum number of dislikes, indicating that it didn't generate as much negative feedback or controversy compared to other videos in the dataset. The content of this video likely did not extract strong negative reactions from the audience, resulting in a low number of dislikes.

# %% [markdown]
# ## Q.13) Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
# Analyze the relationship between views and dislikes
corr = data_set["view_count"].corr(data_set["dislikes"])
corr
# Out:
# 0.6844687753905542

# %%
import matplotlib.pyplot as plot

# %%
# data
X = data_set["view_count"]
Y = data_set["dislikes"]
plot.scatter(X,Y,c='purple')
plot.xlabel('Views')
plot.ylabel('Dislikes')
plot.title(f"Correlation between Views and Dislikes is : {corr:.2f}")
plot.show()

# %% [markdown]
# ### inferences:

# %% [markdown]
# - The correlation coefficient between number of views and the number of dislikes is approximately 0.68
# - it's indicates that positive relationship between the number of views and the number of dislikes. As the number of views increases, the number   of dislikes tends to increase as well.

# %% [markdown]
# ## Q.14) Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
data_set["published_at"]=pd.to_datetime(data_set["published_at"])
data_set["published_month"]=data_set["published_at"].dt.month
videos_january = data_set[data_set["published_month"]==1]
videos_january
# Out:
#           video_id                                              title  \
# 27     -2Gwm7QfBnE                                    Q&A With Naisha
# 48     -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95     -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103    -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182    -JhqO2KWr5U                                   Schlatt gets fit
# ...            ...                                                ...
# 37300  zmzFL5bG-jc  DEVINE MON PERSONNAGE AVANT AKINATOR ! (c'est ...
# 37329  zpzjex7qwrA  Lampard Sacked Within Days Rorys Misery | Chel...
# 37345  zqyv-B6mnBM                 Lil Wayne - Ain't Got Time (Audio)
# 37383  zwfu1-24T7Q  PRADA Cup Day 1 | Full Race Replay | PRADA Cup...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
#
#                      channel_id       channel_title        published_at  \
# ...

# %%
print("summary statistics of the videos published in january : ")
videos_january.describe()
# Out:
# summary statistics of the videos published in january :
#                         published_at    view_count         likes  \
# count                           2108  2.108000e+03  2.108000e+03
# mean   2021-01-17 11:32:44.133301504  4.976449e+06  1.315030e+05
# min              2021-01-01 00:00:54  2.845000e+04  2.800000e+01
# 25%    2021-01-09 22:42:18.750000128  4.322335e+05  1.032400e+04
# 50%              2021-01-17 18:35:30  1.147500e+06  3.173900e+04
# 75%    2021-01-25 14:00:07.750000128  3.227483e+06  1.076512e+05
# max              2021-01-31 23:15:09  6.203274e+08  7.828036e+06
# std                              NaN  2.055331e+07  3.886887e+05
#
#             dislikes  comment_count  published_month
# count    2108.000000   2.108000e+03           2108.0
# mean     3614.568311   8.923385e+03              1.0
# min         3.000000   0.000000e+00              1.0
# 25%       249.000000   8.747500e+02              1.0
# 50%       729.000000   2.328500e+03              1.0
# ...

# %%
print("The count of videos published in January:")
videos_january.shape[0]
# Out:
# The count of videos published in January:
# 2108
